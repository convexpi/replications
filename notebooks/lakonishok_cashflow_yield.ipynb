# %% [markdown]
# # Cash-flow yield (value) — reference replication
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/convexpi/replications/blob/main/notebooks/lakonishok_cashflow_yield.ipynb)
#
# Replication of **Contrarian Investment, Extrapolation, and Risk** (1994). It recomputes the strategy from its building blocks and runs the out-of-sample (McLean & Pontiff) test on live data.
#
# Source: [`replications/catalog/lakonishok_cashflow_yield.py`](https://github.com/convexpi/replications/blob/main/replications/catalog/lakonishok_cashflow_yield.py)

# %%
# !pip -q install "convexpi-replications[extras] @ git+https://github.com/convexpi/replications.git"

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from replications import all_replications
r = all_replications()['lakonishok_cashflow_yield']
rc = r.report_card()
print(rc['title'], '\u2014 verdict:', rc['verdict'])
print('IS Sharpe :', rc['in_sample_sharpe'])
print('OOS Sharpe:', rc['oos_sharpe'], ' (decay:', rc['sharpe_decay'], ')')

# %%
s = r.build().dropna()
(1 + s).cumprod().plot(logy=True, figsize=(9,4), title=rc['title'] + ' (recomputed)')
plt.axvline(pd.Timestamp(f"{r.pub_year}-01-01"), color='crimson', ls='--', label='published')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Your turn
# Change the split year, add costs, or fork the catalog module and improve the replication — then open a PR at [https://github.com/convexpi/replications](https://github.com/convexpi/replications).
